# %% [markdown]
# ## SENTENCE ALIGNER FOR PARALLEL DATA COLLECTION

# %% [markdown]
# ### This code applies [Sentence Transformers](https://www.sbert.net/) (Neils Reimers & Iryna Gurevych, 2019)

# %%
# Import and load Spacy
import spacy
from spacy.lang.es import Spanish
import re
import os

# %%
# Import and load sentence transformers
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('distiluse-base-multilingual-cased')

# %%
# Extend set of characters defining the sentence boundary (e.g. new line)
@Spanish.component("set_custom_boundaries")
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        if token.text == "\n\n":
            doc[token.i + 1].is_sent_start = True
        elif token.text == "\n":
            doc[token.i + 1].is_sent_start = True
        elif token.text == "\r":
            doc[token.i + 1].is_sent_start = True
    return doc
nlp = Spanish()
nlp.add_pipe("set_custom_boundaries")
nlp.add_pipe("sentencizer")

# %%
# Read pair of files
def read_files(source_file, target_file):
    SourceSents = []
    TargetSents = []
    with open(source_file, 'r', encoding='utf8', newline = '') as source, open(target_file, 'r', encoding='utf8', newline = '') as target:
        doc_src = nlp(source.read())
        doc_trg = nlp(target.read())
        for i,sentence in enumerate(doc_src.sents):
            # Do not print empty sentences and do not use sentences made up only of numbers 
            if not (sentence.text.isspace()) and (sentence.text.strip(".").isnumeric()==False):
                # remove spaces at the beginning of the sentence
                sentence = re.sub("^[\n\t\s]+","",sentence.text)
                sentence = sentence.strip()
                SourceSents.append(sentence)
        for i,sentence in enumerate(doc_trg.sents):
            # Do not print empty sentences and do not use sentences made up only of numbers 
            if not (sentence.text.isspace()) and (sentence.text.strip(".").isnumeric()==False):
                # remove sentences at the beginning of the sentence
                sentence = re.sub("^[\n\t\s]+","",sentence.text)
                sentence = sentence.strip()
                TargetSents.append(sentence)
    return SourceSents, TargetSents

# %%
def align_sentences(SentencesSource, SentencesTarget, model, results_file):
    
    ''' Align sentences according to cosine similarity value '''
    
    # Encode source and target sentences
    embeddingsSource = model.encode(SentencesSource, convert_to_tensor=True)
    embeddingsTarget = model.encode(SentencesTarget, convert_to_tensor=True)
    
    # Compute cosine similarity between all pairs
    cos_sim = util.cos_sim(embeddingsSource, embeddingsTarget)
    
    pairs = []
    for i in range(len(SentencesSource)):
        # Save scores per sentence in source data
        sentencePairs = []
        for j in range(len(SentencesTarget)): 
            cos_sim_value = cos_sim[i][j] 
            cos_sim_value = cos_sim_value.item() 
            if (cos_sim_value < 0.999) and cos_sim_value > 0.6:
                sentencePairs.append({'index': [i, j], 'score': cos_sim[i][j]})
                
        # Sort scores for each sentence in decreasing order
        sentencePairs = sorted(sentencePairs, key=lambda x: x['score'], reverse=True)
        pairs.append(sentencePairs)
    
    # Save tuples of (source,target) sentences to avoid repeated pairs
    TupleList = []

    # For each source sentence, print the 3 most similar according to cosine similarity
    k=0
    for n,sentencePairs in enumerate(pairs):
        for m,sentencePair in enumerate(sentencePairs[0:2]):
            if (m==0):
                k = k+1
            i, j = sentencePair['index']
            Tuple = (SentencesSource[i], SentencesTarget[j])
            if Tuple not in TupleList:
                print("-------------------------------------------------------------------------------------------------------------------------------------------------------------------",file=results_file)
                print("-------------------------------------------------------------------------------------------------------------------")
                print("{}.{} \t\tSOURCE: {} \t\tTARGET: {} \t\t Score: {:.4f}".format(k, m, SentencesSource[i], SentencesTarget[j], sentencePair['score']),file=results_file)
                print("{}.{} \t\tSOURCE: {} \t\tTARGET: {} \t\t Score: {:.4f}".format(k, m, SentencesSource[i], SentencesTarget[j], sentencePair['score']))
            TupleList.append(Tuple)

# %%
Data = {}

# Read data folder
DIR = "../corpus/nci/source"
outFile = open("aligned_sentences.txt",'w',encoding='utf-8')

for base, dirs, files in os.walk(DIR):
    for file in files:
        src_file_path = os.path.join(base,file)
        file_id = re.sub("\.src","",file)
        print("ALIGNED SENTENCES FOR %s:" % (file_id),file=outFile)
        trg_file_path = re.sub("source","target",src_file_path)
        trg_file_path = re.sub("src","trg",trg_file_path)
        SourceSents, TargetSents = read_files(src_file_path, trg_file_path)
        align_sentences(SourceSents, TargetSents, model, outFile)
        print("===================================================================================================================================================================\n",file=outFile)

outFile.close()
# Out:
# -------------------------------------------------------------------------------------------------------------------
# 1.0 		SOURCE: ﻿Náuseas y vómitos relacionados con el tratamiento del cáncer 		TARGET: Náuseas y vómitos relacionados con el tratamiento en los niños 		 Score: 0.6986
# -------------------------------------------------------------------------------------------------------------------
# 1.1 		SOURCE: ﻿Náuseas y vómitos relacionados con el tratamiento del cáncer 		TARGET: Las náuseas y los vómitos son efectos secundarios graves del tratamiento de cáncer. 		 Score: 0.6553
# -------------------------------------------------------------------------------------------------------------------
# 2.0 		SOURCE: Aspectos generales 		TARGET: Información general 		 Score: 0.7586
# -------------------------------------------------------------------------------------------------------------------
# 3.0 		SOURCE: La prevención y el control de las náuseas y los vómitos (emesis) (NyV) son de suma importancia en el tratamiento de los pacientes con cáncer. 		TARGET: Es muy importante prevenir y controlar las náuseas y vómitos de los pacientes con cáncer para que puedan continuar con el tratamiento y llevar a cabo las actividades de su vida cotidiana. 		 Score: 0.7255
# -------------------------------------------------------------------------------------------------------------------
# 4.0 		SOURCE: Las NyV inducidos por la quimioterapia son uno de los efectos secundarios agudos más angustiantes del tratamiento del cáncer; se presentan en hasta 80 % de los pacientes y pueden tener un efecto importante en la calidad de vida. 		TARGET: Las náuseas y los vómitos son efectos secundarios del tratamiento del cáncer que afectan a la mayoría de los pacientes que reciben quimioterapia. 		 Score: 0.6326
# -------------------------------------------------------------------------------------------------------------------
# 5.0 		SOURCE: + Alteraciones metabólicas graves. 		TARGET: + Biorretroalimentación. 		 Score: 0.6561
# -------------------------------------------------------------------------------------------------------------------
# 5.1 		SOURCE: + Alteraciones metabólicas graves. 		TARGET: + Desnutrición. 		 Score: 0.6532
# -------------------------------------------------------------------------------------------------------------------
# 6.0 		SOURCE: + Desnutrición y anorexia. 		TARGET: + Desnutrición. 		 Score: 0.8781
# -------------------------------------------------------------------------------------------------------------------
# 6.1 		SOURCE: + Desnutrición y anorexia. 		TARGET: + Pérdida de apetito. 		 Score: 0.7796
# -------------------------------------------------------------------------------------------------------------------
# 7.0 		SOURCE: + Desgarros esofágicos. 		TARGET: + Pérdida de apetito. 		 Score: 0.8847
# -------------------------------------------------------------------------------------------------------------------
# 7.1 		SOURCE: + Desgarros esofágicos. 		TARGET: + Está desnutrido. 		 Score: 0.8167
# -------------------------------------------------------------------------------------------------------------------
# 8.0 		SOURCE: + Fracturas. 		TARGET: + Acupuntura. 		 Score: 0.9344
# -------------------------------------------------------------------------------------------------------------------
# 8.1 		SOURCE: + Fracturas. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.8480
# -------------------------------------------------------------------------------------------------------------------
# 9.0 		SOURCE: + Dehiscencia de los bordes de una herida. 		TARGET: + Huesos rotos. 		 Score: 0.7321
# -------------------------------------------------------------------------------------------------------------------
# 9.1 		SOURCE: + Dehiscencia de los bordes de una herida. 		TARGET: + Heridas quirúrgicas que se vuelve a abrir después de sanar. 		 Score: 0.6766
# -------------------------------------------------------------------------------------------------------------------
# 10.0 		SOURCE: Las náuseas son un fenómeno subjetivo de una sensación desagradable en forma de onda que se siente en la parte posterior de la garganta o el epigastrio, y que puede culminar en vómito (emesis). 		TARGET: La náusea es una sensación desagradable en la parte posterior de la garganta o el estómago que viene y se va en oleadas. 		 Score: 0.7466
# -------------------------------------------------------------------------------------------------------------------
# 11.0 		SOURCE: El vómito es la expulsión forzosa del contenido del estómago, el duodeno o el yeyuno a través de la cavidad oral. 		TARGET: Vomitar es arrojar el contenido del estómago a través de la boca. 		 Score: 0.6729
# -------------------------------------------------------------------------------------------------------------------
# 11.1 		SOURCE: El vómito es la expulsión forzosa del contenido del estómago, el duodeno o el yeyuno a través de la cavidad oral. 		TARGET: La náusea es una sensación desagradable en la parte posterior de la garganta o el estómago que viene y se va en oleadas. 		 Score: 0.6211
# -------------------------------------------------------------------------------------------------------------------
# 12.0 		SOURCE: Las arcadas son movimientos gástricos y esofágicos que se producen al vomitar, pero sin expulsión de vómito; también se conocen como arcadas secas. 		TARGET: Las arcadas son los movimientos del estómago y el esófago sin vomitar; también se llaman arcadas secas. 		 Score: 0.8735
# -------------------------------------------------------------------------------------------------------------------
# 13.0 		SOURCE: El sistema nervioso autónomo controla las náuseas. 		TARGET: Una parte del sistema nervioso autónomo controla las náuseas. 		 Score: 0.8984
# -------------------------------------------------------------------------------------------------------------------
# 14.0 		SOURCE: + Incidencia y gravedad de las NyV durante los ciclos anteriores de quimioterapia. 		TARGET: + Presentó náuseas y vómitos después de sesiones anteriores de quimioterapia. 		 Score: 0.6474
# -------------------------------------------------------------------------------------------------------------------
# 14.1 		SOURCE: + Incidencia y gravedad de las NyV durante los ciclos anteriores de quimioterapia. 		TARGET: + Padeció de náuseas y vómitos graves o frecuentes después de los tratamientos de quimioterapia anteriores. 		 Score: 0.6384
# -------------------------------------------------------------------------------------------------------------------
# 15.0 		SOURCE: Los pacientes con antecedentes de consumo crónico excesivo de bebidas alcohólicas tienen una probabilidad más baja de padecer de NyV a causa del cisplatino. 		TARGET: Los pacientes que consumieron grandes cantidades de bebidas alcohólicas durante un tiempo tienen un riesgo más bajo de náuseas y vómitos después del tratamiento con quimioterapia. 		 Score: 0.6073
# -------------------------------------------------------------------------------------------------------------------
# 16.0 		SOURCE: + Edad. 		TARGET: + Acupuntura. 		 Score: 0.7302
# -------------------------------------------------------------------------------------------------------------------
# 16.1 		SOURCE: + Edad. 		TARGET: + Tener menos de 50 años. 		 Score: 0.7123
# -------------------------------------------------------------------------------------------------------------------
# 17.0 		SOURCE: + Sexo. 		TARGET: + Acupuntura. 		 Score: 0.8084
# -------------------------------------------------------------------------------------------------------------------
# 17.1 		SOURCE: + Sexo. 		TARGET: + Acupresión. 		 Score: 0.7038
# -------------------------------------------------------------------------------------------------------------------
# 18.0 		SOURCE: + Antecedentes de náuseas matutinas o emesis durante el embarazo. 		TARGET: + Antecedentes de náuseas durante un embarazo. 		 Score: 0.8778
# -------------------------------------------------------------------------------------------------------------------
# 18.1 		SOURCE: + Antecedentes de náuseas matutinas o emesis durante el embarazo. 		TARGET: + Tiene antecedentes de náuseas durante un embarazo. 		 Score: 0.8096
# -------------------------------------------------------------------------------------------------------------------
# 19.0 		SOURCE: + Invasión tumoral o neoplasia en el tubo gastrointestinal, el hígado o el sistema nervioso central; especialmente en la fosa posterior. 		TARGET: + Presenta un tumor en el tubo gastrointestinal, el hígado o el encéfalo. 		 Score: 0.7541
# -------------------------------------------------------------------------------------------------------------------
# 20.0 		SOURCE: + Estreñimiento. 		TARGET: + Acupuntura. 		 Score: 0.9298
# -------------------------------------------------------------------------------------------------------------------
# 20.1 		SOURCE: + Estreñimiento. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.9080
# -------------------------------------------------------------------------------------------------------------------
# 21.0 		SOURCE: + Ciertos fármacos, como los opioides. 		TARGET: + Medicamentos como los opioides. 		 Score: 0.9408
# -------------------------------------------------------------------------------------------------------------------
# 21.1 		SOURCE: + Ciertos fármacos, como los opioides. 		TARGET: + Recibe determinados medicamentos, como opioides (medicamentos para calmar el dolor). 		 Score: 0.7627
# -------------------------------------------------------------------------------------------------------------------
# 22.0 		SOURCE: + Infección o septicemia. 		TARGET: + Tiene una enfermedad en los riñones. 		 Score: 0.7097
# -------------------------------------------------------------------------------------------------------------------
# 22.1 		SOURCE: + Infección o septicemia. 		TARGET: + Deshidratación. 		 Score: 0.6702
# -------------------------------------------------------------------------------------------------------------------
# 23.0 		SOURCE: + Uremia. 		TARGET: + Acupuntura. 		 Score: 0.8518
# -------------------------------------------------------------------------------------------------------------------
# 23.1 		SOURCE: + Uremia. 		TARGET: + Acupresión. 		 Score: 0.7772
# -------------------------------------------------------------------------------------------------------------------
# 24.0 		SOURCE: + Náuseas y vómitos agudos: se consideran agudos cuando las NyV se presentan durante las primeras 24 horas de administración de la quimioterapia. 		TARGET: + Diferidos (demorados): náuseas y vómitos que se presentan después de 24 horas del comienzo de la quimioterapia. 		 Score: 0.8184
# -------------------------------------------------------------------------------------------------------------------
# 24.1 		SOURCE: + Náuseas y vómitos agudos: se consideran agudos cuando las NyV se presentan durante las primeras 24 horas de administración de la quimioterapia. 		TARGET: + Agudos: náuseas y vómitos que se presentan en las primeras 24 horas después del comienzo del tratamiento. 		 Score: 0.7915
# -------------------------------------------------------------------------------------------------------------------
# 25.0 		SOURCE: + Náuseas y vómitos diferidos (o tardíos): se consideran diferidos o tardíos cuando las NyV se presentan durante las primeras 24 horas de administración de la quimioterapia. 		TARGET: + Diferidos (demorados): náuseas y vómitos que se presentan después de 24 horas del comienzo de la quimioterapia. 		 Score: 0.8140
# -------------------------------------------------------------------------------------------------------------------
# 25.1 		SOURCE: + Náuseas y vómitos diferidos (o tardíos): se consideran diferidos o tardíos cuando las NyV se presentan durante las primeras 24 horas de administración de la quimioterapia. 		TARGET: + Agudos: náuseas y vómitos que se presentan en las primeras 24 horas después del comienzo del tratamiento. 		 Score: 0.7132
# -------------------------------------------------------------------------------------------------------------------
# 26.0 		SOURCE: + Náuseas y vómitos anticipatorios: las NyV anticipatorios (NVA) son aquellos que se presentan antes de comenzar un nuevo ciclo de quimioterapia como respuesta a estímulos condicionados; por ejemplo, olores, objetos y sonidos de la sala de tratamiento. 		TARGET: + Anticipatorios: náuseas y vómitos que se presentan antes de comenzar la quimioterapia. 		 Score: 0.6016
# -------------------------------------------------------------------------------------------------------------------
# 27.0 		SOURCE: Las NVA son una respuesta condicionada clásica que, por lo general, ocurre después de que el paciente padece de NyV agudos o diferidos durante 3 o 4 tratamientos de quimioterapia. 		TARGET: Por lo general, esto pasa después del tercer o cuarto tratamiento. 		 Score: 0.6098
# -------------------------------------------------------------------------------------------------------------------
# 28.0 		SOURCE: + Náuseas y vómitos intercurrentes: se llaman NyV intercurrentes los vómitos que se presentan dentro de los 5 días siguientes a la administración de antieméticos profilácticos y para los que se necesita tratamiento de rescate. 		TARGET: + Intercurrentes (episódicos): náuseas y vómitos que se presentan dentro de los 5 días posteriores al tratamiento para aliviar las náuseas. 		 Score: 0.7846
# -------------------------------------------------------------------------------------------------------------------
# 29.0 		SOURCE: + Náuseas y vómitos resistentes al tratamiento: son las NyV que no mejoran con el tratamiento. 		TARGET: + Resistentes al tratamiento: náuseas y vómitos que no responden bien a los medicamentos. 		 Score: 0.7784
# -------------------------------------------------------------------------------------------------------------------
# 29.1 		SOURCE: + Náuseas y vómitos resistentes al tratamiento: son las NyV que no mejoran con el tratamiento. 		TARGET: + Crónicos: náuseas y vómitos que permanecen durante un tiempo después de terminar el tratamiento. 		 Score: 0.6423
# -------------------------------------------------------------------------------------------------------------------
# 30.0 		SOURCE: + Náuseas y vómitos crónicos en los pacientes de cáncer en estadio avanzado: las NyV crónicos en pacientes de cáncer en estadio avanzado se relacionan con una variedad de causas posibles. 		TARGET: + Otras afecciones también aumentan el riesgo de náuseas y vómitos en los pacientes de cáncer en estadio avanzado. 		 Score: 0.6292
# -------------------------------------------------------------------------------------------------------------------
# 30.1 		SOURCE: + Náuseas y vómitos crónicos en los pacientes de cáncer en estadio avanzado: las NyV crónicos en pacientes de cáncer en estadio avanzado se relacionan con una variedad de causas posibles. 		TARGET: A continuación se describen las causas de náuseas y vómitos crónicos en los pacientes de cáncer avanzado: 		 Score: 0.6171
# -------------------------------------------------------------------------------------------------------------------
# 31.0 		SOURCE: c Definición: trastorno que se caracteriza por el acto reflejo de expulsar los contenidos del estómago a través de la boca. 		TARGET: Vomitar es arrojar el contenido del estómago a través de la boca. 		 Score: 0.6470
# -------------------------------------------------------------------------------------------------------------------
# 32.0 		SOURCE: Náuseas y vómitos anticipatorios 		TARGET: Náuseas y vómitos agudos o diferidos 		 Score: 0.7107
# -------------------------------------------------------------------------------------------------------------------
# 32.1 		SOURCE: Náuseas y vómitos anticipatorios 		TARGET: Información adicional sobre las náuseas y los vómitos 		 Score: 0.6483
# -------------------------------------------------------------------------------------------------------------------
# 33.0 		SOURCE: Prevalencia 		TARGET: Causas 		 Score: 0.6400
# -------------------------------------------------------------------------------------------------------------------
# 34.0 		SOURCE: Variables correlacionadas con las náuseas y los vómitos anticipatorios 		TARGET: Náuseas y vómitos anticipatorios 		 Score: 0.6343
# -------------------------------------------------------------------------------------------------------------------
# 34.1 		SOURCE: Variables correlacionadas con las náuseas y los vómitos anticipatorios 		TARGET: Náuseas y vómitos agudos o diferidos 		 Score: 0.6058
# -------------------------------------------------------------------------------------------------------------------
# 35.0 		SOURCE: Edad menor de 50 años. 		TARGET: + Tiene menos de 50 años. 		 Score: 0.8677
# -------------------------------------------------------------------------------------------------------------------
# 36.0 		SOURCE: NyV después de la sesión anterior de quimioterapia. 		TARGET: + Presentó náuseas y vómitos después de sesiones anteriores de quimioterapia. 		 Score: 0.7002
# -------------------------------------------------------------------------------------------------------------------
# 36.1 		SOURCE: NyV después de la sesión anterior de quimioterapia. 		TARGET: + Frecuencia de las náuseas después de quimioterapia. 		 Score: 0.6489
# -------------------------------------------------------------------------------------------------------------------
# 37.0 		SOURCE: Vómitos después del tratamiento descritos como moderados, intensos o intolerables. 		TARGET: Las náuseas y vómitos se presentan antes, durante o después del tratamiento. 		 Score: 0.6347
# -------------------------------------------------------------------------------------------------------------------
# 38.0 		SOURCE: Sexo femenino. 		TARGET: + Ser mujer. 		 Score: 0.7608
# -------------------------------------------------------------------------------------------------------------------
# 38.1 		SOURCE: Sexo femenino. 		TARGET: + Es mujer. 		 Score: 0.7089
# -------------------------------------------------------------------------------------------------------------------
# 39.0 		SOURCE: Estado de ansiedad alto (ansiedad reactiva ante situaciones específicas). 		TARGET: + Tener grados altos de ansiedad en determinadas situaciones. 		 Score: 0.6379
# -------------------------------------------------------------------------------------------------------------------
# 40.0 		SOURCE: Expectativas del paciente de sufrir náuseas relacionadas con la quimioterapia antes de comenzar el tratamiento. 		TARGET: + Expectativas de tener náuseas y vómitos antes del inicio de la quimioterapia. 		 Score: 0.7626
# -------------------------------------------------------------------------------------------------------------------
# 40.1 		SOURCE: Expectativas del paciente de sufrir náuseas relacionadas con la quimioterapia antes de comenzar el tratamiento. 		TARGET: Si el paciente sufrió de náuseas y vómitos después de una sesión de quimioterapia anterior, quizá tenga náuseas y vómitos anticipatorios antes del siguiente tratamiento. 		 Score: 0.6027
# -------------------------------------------------------------------------------------------------------------------
# 41.0 		SOURCE: Porcentaje de infusiones de quimioterapia seguidas de náuseas. 		TARGET: + Frecuencia de las náuseas después de quimioterapia. 		 Score: 0.6423
# -------------------------------------------------------------------------------------------------------------------
# 41.1 		SOURCE: Porcentaje de infusiones de quimioterapia seguidas de náuseas. 		TARGET: + Recibe tratamiento con determinados medicamentos de quimioterapia. 		 Score: 0.6226
# -------------------------------------------------------------------------------------------------------------------
# 42.0 		SOURCE: Mareo después de la quimioterapia. 		TARGET: + Frecuencia de las náuseas después de quimioterapia. 		 Score: 0.7874
# -------------------------------------------------------------------------------------------------------------------
# 42.1 		SOURCE: Mareo después de la quimioterapia. 		TARGET: + Sensación de mareo o vértigo después de la quimioterapia. 		 Score: 0.6884
# -------------------------------------------------------------------------------------------------------------------
# 43.0 		SOURCE: Potencial emetógeno de varios fármacos quimioterapéuticos. 		TARGET: + Recibe tratamiento con determinados medicamentos de quimioterapia. 		 Score: 0.6675
# -------------------------------------------------------------------------------------------------------------------
# 43.1 		SOURCE: Potencial emetógeno de varios fármacos quimioterapéuticos. 		TARGET: Es posible que las náuseas y vómitos anticipatorios se presenten después de varios tratamientos de quimioterapia. 		 Score: 0.6269
# -------------------------------------------------------------------------------------------------------------------
# 44.0 		SOURCE: Antecedentes de náuseas matutinas durante el embarazo. 		TARGET: + Antecedentes de náuseas durante un embarazo. 		 Score: 0.7998
# -------------------------------------------------------------------------------------------------------------------
# 44.1 		SOURCE: Antecedentes de náuseas matutinas durante el embarazo. 		TARGET: + Tiene antecedentes de náuseas durante un embarazo. 		 Score: 0.7442
# -------------------------------------------------------------------------------------------------------------------
# 45.0 		SOURCE: Tratamiento de las náuseas y los vómitos anticipatorios 		TARGET: Náuseas y vómitos anticipatorios 		 Score: 0.8281
# -------------------------------------------------------------------------------------------------------------------
# 45.1 		SOURCE: Tratamiento de las náuseas y los vómitos anticipatorios 		TARGET: Tratamiento de las náuseas y vómitos sin medicamentos 		 Score: 0.7825
# -------------------------------------------------------------------------------------------------------------------
# 46.0 		SOURCE: + Relajamiento muscular progresivo con imágenes guiadas. 		TARGET: + Relajación muscular e imágenes guiadas. 		 Score: 0.8712
# -------------------------------------------------------------------------------------------------------------------
# 46.1 		SOURCE: + Relajamiento muscular progresivo con imágenes guiadas. 		TARGET: + Entrenamiento de relajación muscular. 		 Score: 0.7441
# -------------------------------------------------------------------------------------------------------------------
# 47.0 		SOURCE: + Hipnosis. 		TARGET: + Acupresión. 		 Score: 0.7317
# -------------------------------------------------------------------------------------------------------------------
# 47.1 		SOURCE: + Hipnosis. 		TARGET: + Acupuntura. 		 Score: 0.7111
# -------------------------------------------------------------------------------------------------------------------
# 48.0 		SOURCE: + Desensibilización sistemática. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.6800
# -------------------------------------------------------------------------------------------------------------------
# 48.1 		SOURCE: + Desensibilización sistemática. 		TARGET: + Hipnosis. 		 Score: 0.6742
# -------------------------------------------------------------------------------------------------------------------
# 49.0 		SOURCE: + Electromiografía y biorretroalimentación térmica. 		TARGET: + Biorretroalimentación. 		 Score: 0.7224
# -------------------------------------------------------------------------------------------------------------------
# 50.0 		SOURCE: + Distracción mediante videojuegos. 		TARGET: + Distracciones (como los videojuegos). 		 Score: 0.8919
# -------------------------------------------------------------------------------------------------------------------
# 50.1 		SOURCE: + Distracción mediante videojuegos. 		TARGET: + Juegos de realidad virtual. 		 Score: 0.6439
# -------------------------------------------------------------------------------------------------------------------
# 51.0 		SOURCE: Características etiológicas de las náuseas y los vómitos agudos o diferidos inducidos por la quimioterapia 		TARGET: Las náuseas y vómitos agudos o diferidos son comunes en los pacientes tratados con quimioterapia. 		 Score: 0.6228
# -------------------------------------------------------------------------------------------------------------------
# 52.0 		SOURCE: Náuseas y vómitos agudos 		TARGET: Náuseas y vómitos anticipatorios 		 Score: 0.8562
# -------------------------------------------------------------------------------------------------------------------
# 52.1 		SOURCE: Náuseas y vómitos agudos 		TARGET: Náuseas y vómitos agudos o diferidos 		 Score: 0.7990
# -------------------------------------------------------------------------------------------------------------------
# 53.0 		SOURCE: Los factores de riesgo son, entre otros, los siguientes: 		TARGET: Los siguientes factores del tratamiento quizá afecten el riesgo de náuseas y vómitos: 		 Score: 0.6646
# -------------------------------------------------------------------------------------------------------------------
# 54.0 		SOURCE: + El potencial emetógeno del fármaco específico. 		TARGET: + El medicamento específico que se administra. 		 Score: 0.7812
# -------------------------------------------------------------------------------------------------------------------
# 54.1 		SOURCE: + El potencial emetógeno del fármaco específico. 		TARGET: + La forma de administración del medicamento. 		 Score: 0.6200
# -------------------------------------------------------------------------------------------------------------------
# 55.0 		SOURCE: + La dosis utilizada. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.6803
# -------------------------------------------------------------------------------------------------------------------
# 55.1 		SOURCE: + La dosis utilizada. 		TARGET: + La forma de administración del medicamento. 		 Score: 0.6677
# -------------------------------------------------------------------------------------------------------------------
# 56.0 		SOURCE: + El plan de tratamiento. 		TARGET: + Terapia del comportamiento. 		 Score: 0.6917
# -------------------------------------------------------------------------------------------------------------------
# 56.1 		SOURCE: + El plan de tratamiento. 		TARGET: + El tamaño del área en tratamiento. 		 Score: 0.6389
# -------------------------------------------------------------------------------------------------------------------
# 57.0 		SOURCE: + La forma en que se combinan los fármacos de quimioterapia. 		TARGET: + Recibe tratamiento con determinados medicamentos de quimioterapia. 		 Score: 0.7752
# -------------------------------------------------------------------------------------------------------------------
# 57.1 		SOURCE: + La forma en que se combinan los fármacos de quimioterapia. 		TARGET: + Frecuencia de las náuseas después de quimioterapia. 		 Score: 0.7101
# -------------------------------------------------------------------------------------------------------------------
# 58.0 		SOURCE: Otros factores de riesgo son los siguientes: 		TARGET: Los siguientes factores del tratamiento quizá afecten el riesgo de náuseas y vómitos: 		 Score: 0.6498
# -------------------------------------------------------------------------------------------------------------------
# 59.0 		SOURCE: + Control insuficiente de los síntomas durante la quimioterapia anterior. 		TARGET: + Frecuencia de las náuseas después de quimioterapia. 		 Score: 0.7038
# -------------------------------------------------------------------------------------------------------------------
# 59.1 		SOURCE: + Control insuficiente de los síntomas durante la quimioterapia anterior. 		TARGET: + Recibió quimioterapia en el pasado. 		 Score: 0.6988
# -------------------------------------------------------------------------------------------------------------------
# 60.0 		SOURCE: + Sexo femenino. 		TARGET: + Ser mujer. 		 Score: 0.8852
# -------------------------------------------------------------------------------------------------------------------
# 60.1 		SOURCE: + Sexo femenino. 		TARGET: + Es mujer. 		 Score: 0.8075
# -------------------------------------------------------------------------------------------------------------------
# 61.0 		SOURCE: + Edad menor de 50 años. 		TARGET: + Tener menos de 50 años. 		 Score: 0.9735
# -------------------------------------------------------------------------------------------------------------------
# 61.1 		SOURCE: + Edad menor de 50 años. 		TARGET: + Tiene menos de 50 años. 		 Score: 0.9339
# -------------------------------------------------------------------------------------------------------------------
# 62.0 		SOURCE: + Experiencia durante la quimioterapia anterior. 		TARGET: + Recibió quimioterapia en el pasado. 		 Score: 0.8097
# -------------------------------------------------------------------------------------------------------------------
# 62.1 		SOURCE: + Experiencia durante la quimioterapia anterior. 		TARGET: + Frecuencia de las náuseas después de quimioterapia. 		 Score: 0.7508
# -------------------------------------------------------------------------------------------------------------------
# 63.0 		SOURCE: + Antecedentes de cinetosis. 		TARGET: + Tener antecedentes de mareos. 		 Score: 0.9009
# -------------------------------------------------------------------------------------------------------------------
# 63.1 		SOURCE: + Antecedentes de cinetosis. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.8155
# -------------------------------------------------------------------------------------------------------------------
# 64.0 		SOURCE: + Antecedentes de náuseas matutinas durante el embarazo. 		TARGET: + Antecedentes de náuseas durante un embarazo. 		 Score: 0.9535
# -------------------------------------------------------------------------------------------------------------------
# 64.1 		SOURCE: + Antecedentes de náuseas matutinas durante el embarazo. 		TARGET: + Tiene antecedentes de náuseas durante un embarazo. 		 Score: 0.8861
# -------------------------------------------------------------------------------------------------------------------
# 65.0 		SOURCE: + Deshidratación. 		TARGET: + Está deshidratado. 		 Score: 0.8978
# -------------------------------------------------------------------------------------------------------------------
# 65.1 		SOURCE: + Deshidratación. 		TARGET: + Desnutrición. 		 Score: 0.7372
# -------------------------------------------------------------------------------------------------------------------
# 66.0 		SOURCE: + Desnutrición. 		TARGET: + Pérdida de apetito. 		 Score: 0.8635
# -------------------------------------------------------------------------------------------------------------------
# 66.1 		SOURCE: + Desnutrición. 		TARGET: + Está desnutrido. 		 Score: 0.8241
# -------------------------------------------------------------------------------------------------------------------
# 67.0 		SOURCE: + Cirugía reciente. 		TARGET: + Se sometió a una cirugía reciente. 		 Score: 0.8778
# -------------------------------------------------------------------------------------------------------------------
# 67.1 		SOURCE: + Cirugía reciente. 		TARGET: + Heridas quirúrgicas que se vuelve a abrir después de sanar. 		 Score: 0.6243
# -------------------------------------------------------------------------------------------------------------------
# 68.0 		SOURCE: + Radioterapia. 		TARGET: + Recibió radioterapia. 		 Score: 0.9306
# -------------------------------------------------------------------------------------------------------------------
# 68.1 		SOURCE: + Radioterapia. 		TARGET: + La dosis de radiación. 		 Score: 0.7619
# -------------------------------------------------------------------------------------------------------------------
# 69.0 		SOURCE: Náusea y vómitos diferidos 		TARGET: Náuseas y vómitos agudos o diferidos 		 Score: 0.8657
# -------------------------------------------------------------------------------------------------------------------
# 69.1 		SOURCE: Náusea y vómitos diferidos 		TARGET: Náuseas y vómitos anticipatorios 		 Score: 0.7549
# -------------------------------------------------------------------------------------------------------------------
# 70.0 		SOURCE: Las NyV diferidos (o tardíos) se presentan más de 24 horas después de la administración de quimioterapia. 		TARGET: + Diferidos (demorados): náuseas y vómitos que se presentan después de 24 horas del comienzo de la quimioterapia. 		 Score: 0.6987
# -------------------------------------------------------------------------------------------------------------------
# 71.0 		SOURCE: • Es mucho más probable que los pacientes que presentan emesis aguda durante la quimioterapia experimenten emesis diferida. 		TARGET: A medida que el paciente se somete a más sesiones de quimioterapia, es más probable que presente más náuseas y vómitos anticipatorios. 		 Score: 0.6157
# -------------------------------------------------------------------------------------------------------------------
# 72.0 		SOURCE: Prevención y tratamiento de las náuseas y los vómitos agudos o diferidos 		TARGET: Náuseas y vómitos agudos o diferidos 		 Score: 0.7241
# -------------------------------------------------------------------------------------------------------------------
# 72.1 		SOURCE: Prevención y tratamiento de las náuseas y los vómitos agudos o diferidos 		TARGET: Tratamiento de las náuseas y vómitos sin medicamentos 		 Score: 0.6582
# -------------------------------------------------------------------------------------------------------------------
# 73.0 		SOURCE: dexametasona, palonosetrón y olanzapina. 		TARGET: Dexametasona, metilprednisolona                                  Corticosteroides 		 Score: 0.6007
# -------------------------------------------------------------------------------------------------------------------
# 73.1 		SOURCE: dexametasona, palonosetrón y olanzapina. 		TARGET: Dexametasona, metilprednisolona             Corticosteroides 		 Score: 0.6007
# -------------------------------------------------------------------------------------------------------------------
# 74.0 		SOURCE: En un estudio se indicó que los pacientes con expectativa alta de náuseas parecen presentar más náuseas después de la quimioterapia. 		TARGET: A medida que el paciente se somete a más sesiones de quimioterapia, es más probable que presente más náuseas y vómitos anticipatorios. 		 Score: 0.6371
# -------------------------------------------------------------------------------------------------------------------
# 75.0 		SOURCE: + Antagonistas de la sustancia P (antagonistas del receptor de NK-1) 		TARGET: Aprepitant, fosaprepitant                   Antagonistas de la sustancia P/NK-1 		 Score: 0.7926
# -------------------------------------------------------------------------------------------------------------------
# 75.1 		SOURCE: + Antagonistas de la sustancia P (antagonistas del receptor de NK-1) 		TARGET: Aprepitant, fosaprepitant, netupitant, fosnetupitant, rolapitant Antagonistas de la sustancia P/NK-1 		 Score: 0.6939
# -------------------------------------------------------------------------------------------------------------------
# 76.0 		SOURCE: + Corticoesteroides. 		TARGET: Dexametasona                                       Corticosteroides 		 Score: 0.6631
# -------------------------------------------------------------------------------------------------------------------
# 76.1 		SOURCE: + Corticoesteroides. 		TARGET: + Acupuntura. 		 Score: 0.6042
# -------------------------------------------------------------------------------------------------------------------
# 77.0 		SOURCE: + Benzodiazepinas (lorazepam). 		TARGET: + Medicamentos como los opioides. 		 Score: 0.7230
# -------------------------------------------------------------------------------------------------------------------
# 77.1 		SOURCE: + Benzodiazepinas (lorazepam). 		TARGET: Lorazepam                                   Benzodiazepinas 		 Score: 0.6554
# -------------------------------------------------------------------------------------------------------------------
# 78.0 		SOURCE: + Canabinoides. 		TARGET: + Acupuntura. 		 Score: 0.7425
# -------------------------------------------------------------------------------------------------------------------
# 78.1 		SOURCE: + Canabinoides. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.6955
# -------------------------------------------------------------------------------------------------------------------
# 79.0 		SOURCE: Prevención de las náuseas y los vómitos agudos o diferidos causados por la quimioterapia 		TARGET: CAPTION: Medicamentos usados para prevenir las náuseas y vómitos causados por quimioterapia 		 Score: 0.7036
# -------------------------------------------------------------------------------------------------------------------
# 80.0 		SOURCE: Antiemético de efecto débil 		TARGET: Olanzapina                                  Antipsicóticos atípicos 		 Score: 0.6110
# -------------------------------------------------------------------------------------------------------------------
# 81.0 		SOURCE: Benzamidas sustituidas 		TARGET: Lorazepam                                   Benzodiazepinas 		 Score: 0.6095
# -------------------------------------------------------------------------------------------------------------------
# 82.0 		SOURCE: En los Estados Unidos se comercializan cuatro antagonistas de los receptores de serotonina: ondansetrón, granisetrón, dolasetrón y palonosetrón. 		TARGET: Dolasetrón, granisetrón, ondansetrón, palonosetrón               Antagonistas del receptor de serotonina 		 Score: 0.6814
# -------------------------------------------------------------------------------------------------------------------
# 82.1 		SOURCE: En los Estados Unidos se comercializan cuatro antagonistas de los receptores de serotonina: ondansetrón, granisetrón, dolasetrón y palonosetrón. 		TARGET: Granisetrón, ondansetrón, palonosetrón, dolasetrón Antagonistas del receptor de serotonina 		 Score: 0.6789
# -------------------------------------------------------------------------------------------------------------------
# 83.0 		SOURCE: + Cefalea (se trata con analgésicos suaves). 		TARGET: + Recibe determinados medicamentos, como opioides (medicamentos para calmar el dolor). 		 Score: 0.6416
# -------------------------------------------------------------------------------------------------------------------
# 85.0 		SOURCE: + Fatiga. 		TARGET: + Acupuntura. 		 Score: 0.9227
# -------------------------------------------------------------------------------------------------------------------
# 85.1 		SOURCE: + Fatiga. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.7950
# -------------------------------------------------------------------------------------------------------------------
# 86.0 		SOURCE: + Xerostomía. 		TARGET: + Hipnosis. 		 Score: 0.8213
# -------------------------------------------------------------------------------------------------------------------
# 87.0 		SOURCE: Antagonistas del receptor de NK-1 (antagonistas de la sustancia P) 		TARGET: Aprepitant, fosaprepitant                   Antagonistas de la sustancia P/NK-1 		 Score: 0.8135
# -------------------------------------------------------------------------------------------------------------------
# 87.1 		SOURCE: Antagonistas del receptor de NK-1 (antagonistas de la sustancia P) 		TARGET: Aprepitant, fosaprepitant, netupitant, fosnetupitant, rolapitant Antagonistas de la sustancia P/NK-1 		 Score: 0.7133
# -------------------------------------------------------------------------------------------------------------------
# 88.0 		SOURCE: Los antagonistas del receptor de NK-1, como aprepitant, fosaprepitant, netupitant, fosnetupitant y rolapitant, bloquean la unión de la sustancia P con el receptor de NK-1. 		TARGET: Aprepitant, fosaprepitant, netupitant, fosnetupitant, rolapitant Antagonistas de la sustancia P/NK-1 		 Score: 0.7146
# -------------------------------------------------------------------------------------------------------------------
# 88.1 		SOURCE: Los antagonistas del receptor de NK-1, como aprepitant, fosaprepitant, netupitant, fosnetupitant y rolapitant, bloquean la unión de la sustancia P con el receptor de NK-1. 		TARGET: Aprepitant, fosaprepitant                   Antagonistas de la sustancia P/NK-1 		 Score: 0.6257
# -------------------------------------------------------------------------------------------------------------------
# 89.0 		SOURCE: Corticoesteroides 		TARGET: Dexametasona                                       Corticosteroides 		 Score: 0.8519
# -------------------------------------------------------------------------------------------------------------------
# 89.1 		SOURCE: Corticoesteroides 		TARGET: Dexametasona, metilprednisolona             Corticosteroides 		 Score: 0.7446
# -------------------------------------------------------------------------------------------------------------------
# 90.0 		SOURCE: + Inmunodepresión. 		TARGET: + Acupresión. 		 Score: 0.7807
# -------------------------------------------------------------------------------------------------------------------
# 90.1 		SOURCE: + Inmunodepresión. 		TARGET: + Hipnosis. 		 Score: 0.7277
# -------------------------------------------------------------------------------------------------------------------
# 91.0 		SOURCE: + Necrosis aséptica de los huesos largos. 		TARGET: + Huesos rotos. 		 Score: 0.6390
# -------------------------------------------------------------------------------------------------------------------
# 92.0 		SOURCE: + Formación de cataratas. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.7464
# -------------------------------------------------------------------------------------------------------------------
# 92.1 		SOURCE: + Formación de cataratas. 		TARGET: + Acupresión. 		 Score: 0.7012
# -------------------------------------------------------------------------------------------------------------------
# 93.0 		SOURCE: + Inhibición suprarrenal con hipocortisolismo. 		TARGET: + Hipnosis. 		 Score: 0.6323
# -------------------------------------------------------------------------------------------------------------------
# 94.0 		SOURCE: + Letargo. 		TARGET: + Acupuntura. 		 Score: 0.9353
# -------------------------------------------------------------------------------------------------------------------
# 94.1 		SOURCE: + Letargo. 		TARGET: + Acupresión. 		 Score: 0.7995
# -------------------------------------------------------------------------------------------------------------------
# 95.0 		SOURCE: + Aumento de peso. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.7137
# -------------------------------------------------------------------------------------------------------------------
# 95.1 		SOURCE: + Aumento de peso. 		TARGET: + Desnutrición. 		 Score: 0.7080
# -------------------------------------------------------------------------------------------------------------------
# 96.0 		SOURCE: + Irritación gastrointestinaI. 		TARGET: + Tumores del tubo gastrointestinal. 		 Score: 0.8268
# -------------------------------------------------------------------------------------------------------------------
# 96.1 		SOURCE: + Irritación gastrointestinaI. 		TARGET: + Pérdida de apetito. 		 Score: 0.7704
# -------------------------------------------------------------------------------------------------------------------
# 97.0 		SOURCE: + Insomnio. 		TARGET: + Acupuntura. 		 Score: 0.8562
# -------------------------------------------------------------------------------------------------------------------
# 97.1 		SOURCE: + Insomnio. 		TARGET: + Acupresión. 		 Score: 0.7844
# -------------------------------------------------------------------------------------------------------------------
# 98.0 		SOURCE: + Ansiedad. 		TARGET: + Acupresión. 		 Score: 0.8939
# -------------------------------------------------------------------------------------------------------------------
# 98.1 		SOURCE: + Ansiedad. 		TARGET: + Sufre de ansiedad. 		 Score: 0.8779
# -------------------------------------------------------------------------------------------------------------------
# 99.0 		SOURCE: + Cambios de humor. 		TARGET: + Cambios mentales. 		 Score: 0.7949
# -------------------------------------------------------------------------------------------------------------------
# 99.1 		SOURCE: + Cambios de humor. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.6951
# -------------------------------------------------------------------------------------------------------------------
# 100.0 		SOURCE: + Psicosis. 		TARGET: + Hipnosis. 		 Score: 0.8137
# -------------------------------------------------------------------------------------------------------------------
# 101.0 		SOURCE: Benzodiazepinas 		TARGET: Lorazepam                                   Benzodiazepinas 		 Score: 0.8535
# -------------------------------------------------------------------------------------------------------------------
# 101.1 		SOURCE: Benzodiazepinas 		TARGET: Alprazolam, lorazepam                                            Benzodiazepinas 		 Score: 0.7861
# -------------------------------------------------------------------------------------------------------------------
# 102.0 		SOURCE: + Sedación. 		TARGET: + Acupuntura. 		 Score: 0.9185
# -------------------------------------------------------------------------------------------------------------------
# 102.1 		SOURCE: + Sedación. 		TARGET: + Acupresión. 		 Score: 0.9171
# -------------------------------------------------------------------------------------------------------------------
# 104.0 		SOURCE: + Aumento de apetito. 		TARGET: + Pérdida de apetito. 		 Score: 0.9192
# -------------------------------------------------------------------------------------------------------------------
# 104.1 		SOURCE: + Aumento de apetito. 		TARGET: + Desnutrición. 		 Score: 0.8562
# -------------------------------------------------------------------------------------------------------------------
# 106.0 		SOURCE: + Hipotensión postural. 		TARGET: + Hipnosis. 		 Score: 0.7624
# -------------------------------------------------------------------------------------------------------------------
# 107.0 		SOURCE: + Mareos. 		TARGET: + Acupuntura. 		 Score: 0.9260
# -------------------------------------------------------------------------------------------------------------------
# 107.1 		SOURCE: + Mareos. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.8017
# -------------------------------------------------------------------------------------------------------------------
# 108.0 		SOURCE: + Inicial, 0 a 24 horas. 		TARGET: + Agudos: náuseas y vómitos que se presentan en las primeras 24 horas después del comienzo del tratamiento. 		 Score: 0.6526
# -------------------------------------------------------------------------------------------------------------------
# 109.0 		SOURCE: Otros fármacos 		TARGET: Dronabinol, nabilona                        Otros medicamentos 		 Score: 0.7533
# -------------------------------------------------------------------------------------------------------------------
# 109.1 		SOURCE: Otros fármacos 		TARGET: + La dosis del medicamento o si se administra con otros medicamentos. 		 Score: 0.6053
# -------------------------------------------------------------------------------------------------------------------
# 110.0 		SOURCE: Quimioterapia en días múltiples 		TARGET: Además, la mayoría de los tratamientos de quimioterapia utilizados en los niños se programan durante varios días. 		 Score: 0.6057
# -------------------------------------------------------------------------------------------------------------------
# 111.0 		SOURCE: Tratamiento no farmacológico de las náuseas y los vómitos 		TARGET: Tratamiento de las náuseas y vómitos sin medicamentos 		 Score: 0.9631
# -------------------------------------------------------------------------------------------------------------------
# 111.1 		SOURCE: Tratamiento no farmacológico de las náuseas y los vómitos 		TARGET: Náuseas y vómitos relacionados con el tratamiento en los niños 		 Score: 0.6528
# ...
# -------------------------------------------------------------------------------------------------------------------
# 138.0 		SOURCE: Antagonistas del receptor de neurocinina-1 		TARGET: Aprepitant, fosaprepitant                   Antagonistas de la sustancia P/NK-1 		 Score: 0.6362
# -------------------------------------------------------------------------------------------------------------------
# 140.0 		SOURCE: Dosificación de antieméticos para la radioterapiaa 		TARGET: CAPTION: Medicamentos usados para prevenir las náuseas y vómitos causados por radioterapia 		 Score: 0.6778
# -------------------------------------------------------------------------------------------------------------------
# 140.1 		SOURCE: Dosificación de antieméticos para la radioterapiaa 		TARGET: + Recibió radioterapia. 		 Score: 0.6062
# -------------------------------------------------------------------------------------------------------------------
# 141.0 		SOURCE: Categoría farmacológica                Antiemético                Dosis                                                              Comentario                                                           Referencia 		TARGET: Olanzapina                                  Antipsicóticos atípicos 		 Score: 0.6164
# -------------------------------------------------------------------------------------------------------------------
# 141.1 		SOURCE: Categoría farmacológica                Antiemético                Dosis                                                              Comentario                                                           Referencia 		TARGET: Nombre del medicamento                                           Tipo de medicamento 		 Score: 0.6133
# -------------------------------------------------------------------------------------------------------------------
# 142.0 		SOURCE: Directrices antieméticas publicadas sobre náuseas y vómitos en niños 		TARGET: Náuseas y vómitos relacionados con el tratamiento en los niños 		 Score: 0.7127
# -------------------------------------------------------------------------------------------------------------------
# 143.0 		SOURCE: Las náuseas y vómitos (NyV) inducidos por la quimioterapia (NVIQ) son un problema importante para los niños. 		TARGET: Las náuseas y vómitos en los niños tratados con quimioterapia son un problema grave. 		 Score: 0.8181
# -------------------------------------------------------------------------------------------------------------------
# 143.1 		SOURCE: Las náuseas y vómitos (NyV) inducidos por la quimioterapia (NVIQ) son un problema importante para los niños. 		TARGET: + Las náuseas y vómitos en los niños tratados con quimioterapia son un problema grave. 		 Score: 0.7673
# -------------------------------------------------------------------------------------------------------------------
# 144.0 		SOURCE: Al igual que para los adultos, las náuseas en los niños son más problemáticas que el vómito. 		TARGET: Al igual que en los adultos, las náuseas en los niños que reciben quimioterapia son más problemáticas que los vómitos. 		 Score: 0.8203
# -------------------------------------------------------------------------------------------------------------------
# 145.0 		SOURCE: Profilaxis con antieméticos 		TARGET: Olanzapina                                  Antipsicóticos atípicos 		 Score: 0.6823
# -------------------------------------------------------------------------------------------------------------------
# 146.0 		SOURCE: Quimioterapia muy emetógena 		TARGET: + Recibe tratamiento con determinados medicamentos de quimioterapia. 		 Score: 0.6296
# -------------------------------------------------------------------------------------------------------------------
# 147.0 		SOURCE: Quimioterapia moderadamente emetógena 		TARGET: + Recibe tratamiento con determinados medicamentos de quimioterapia. 		 Score: 0.6372
# -------------------------------------------------------------------------------------------------------------------
# 148.0 		SOURCE: Quimioterapia poco emetógena 		TARGET: + Recibe tratamiento con determinados medicamentos de quimioterapia. 		 Score: 0.6257
# -------------------------------------------------------------------------------------------------------------------
# 149.0 		SOURCE: + Acupuntura. 		TARGET: + Acupresión. 		 Score: 0.9011
# -------------------------------------------------------------------------------------------------------------------
# 149.1 		SOURCE: + Acupuntura. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.8735
# -------------------------------------------------------------------------------------------------------------------
# 151.0 		SOURCE: + imaginería guiada. 		TARGET: + Imágenes guiadas. 		 Score: 0.7470
# -------------------------------------------------------------------------------------------------------------------
# 151.1 		SOURCE: + imaginería guiada. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.7418
# -------------------------------------------------------------------------------------------------------------------
# 152.0 		SOURCE: + Musicoterapia. 		TARGET: + Terapia del comportamiento. 		 Score: 0.7176
# -------------------------------------------------------------------------------------------------------------------
# 152.1 		SOURCE: + Musicoterapia. 		TARGET: + Hipnosis. 		 Score: 0.6739
# -------------------------------------------------------------------------------------------------------------------
# 153.0 		SOURCE: + Relajación muscular progresiva. 		TARGET: + Entrenamiento de relajación muscular. 		 Score: 0.9027
# -------------------------------------------------------------------------------------------------------------------
# 153.1 		SOURCE: + Relajación muscular progresiva. 		TARGET: + Relajación muscular e imágenes guiadas. 		 Score: 0.7238
# -------------------------------------------------------------------------------------------------------------------
# 154.0 		SOURCE: + Ingerir alimentos en porciones más pequeñas y frecuentes. 		TARGET: + Consumir comidas más pequeñas más a menudo. 		 Score: 0.8790
# -------------------------------------------------------------------------------------------------------------------
# 155.0 		SOURCE: + Reducir los aromas de los alimentos y otros estímulos con olores fuertes. 		TARGET: + Evitar los olores de los alimentos y otros olores fuertes. 		 Score: 0.8774
# -------------------------------------------------------------------------------------------------------------------
# 156.0 		SOURCE: + Evitar los alimentos picantes, con alto contenido de grasas o muy salados. 		TARGET: + Evitar los alimentos condimentados, grasosos o salados. 		 Score: 0.8974
# -------------------------------------------------------------------------------------------------------------------
# 157.0 		SOURCE: + Tomar los antieméticos antes de comer para que el efecto esté presente durante y después de las comidas. 		TARGET: + Tomar los medicamentos contra las náuseas antes de las comidas. 		 Score: 0.7717
# -------------------------------------------------------------------------------------------------------------------
# 157.1 		SOURCE: + Tomar los antieméticos antes de comer para que el efecto esté presente durante y después de las comidas. 		TARGET: + Consumir "comidas caseras" que ya fueron útiles antes para prevenir las náuseas. 		 Score: 0.6793
# -------------------------------------------------------------------------------------------------------------------
# 158.0 		SOURCE: + Tomar medidas e ingerir alimentos (por ejemplo, "comidas reconfortantes") que en el pasado ayudaron a reducir al mínimo las náuseas. 		TARGET: + Consumir "comidas caseras" que ya fueron útiles antes para prevenir las náuseas. 		 Score: 0.6821
# -------------------------------------------------------------------------------------------------------------------
# 159.0 		SOURCE: Antieméticos 		TARGET: Olanzapina                                  Antipsicóticos atípicos 		 Score: 0.6911
# -------------------------------------------------------------------------------------------------------------------
# 160.0 		SOURCE: Dosificación de antieméticos en pediatría 		TARGET: Olanzapina                                  Antipsicóticos atípicos 		 Score: 0.6072
# -------------------------------------------------------------------------------------------------------------------
# 161.0 		SOURCE: Categoría farmacológica                        Medicamento                                                                                                   Dosis                                                                                                Vía de administración disponible                                                                                                                               Comentario                                                                                                                                                           Referencia 		TARGET: Nombre del medicamento                                           Tipo de medicamento 		 Score: 0.6063
# -------------------------------------------------------------------------------------------------------------------
# 161.1 		SOURCE: Categoría farmacológica                        Medicamento                                                                                                   Dosis                                                                                                Vía de administración disponible                                                                                                                               Comentario                                                                                                                                                           Referencia 		TARGET: Nombre del medicamento                          Tipo de medicamento 		 Score: 0.6063
# -------------------------------------------------------------------------------------------------------------------
# 162.0 		SOURCE: + Doxorrubicina e ifosfamida. 		TARGET: + Medicamentos como los opioides. 		 Score: 0.6497
# -------------------------------------------------------------------------------------------------------------------
# 162.1 		SOURCE: + Doxorrubicina e ifosfamida. 		TARGET: + Náuseas y vómitos 		 Score: 0.6121
# -------------------------------------------------------------------------------------------------------------------
# 163.0 		SOURCE: + Etopósido e ifosfamida. 		TARGET: + Náuseas y vómitos 		 Score: 0.6995
# -------------------------------------------------------------------------------------------------------------------
# 163.1 		SOURCE: + Etopósido e ifosfamida. 		TARGET: + Sufre de estreñimiento. 		 Score: 0.6944
# -------------------------------------------------------------------------------------------------------------------
# 164.0 		SOURCE: Náuseas y vómitos diferidos en niños 		TARGET: Náuseas y vómitos relacionados con el tratamiento en los niños 		 Score: 0.7861
# -------------------------------------------------------------------------------------------------------------------
# 164.1 		SOURCE: Náuseas y vómitos diferidos en niños 		TARGET: Náuseas y vómitos agudos o diferidos 		 Score: 0.7507
# -------------------------------------------------------------------------------------------------------------------
# 165.0 		SOURCE: Además, la mayoría de los regímenes de quimioterapia en pediatría se administran en días múltiples, por lo que se desconoce el comienzo y la duración del riesgo de NyV diferidos versos agudos. 		TARGET: Además, la mayoría de los tratamientos de quimioterapia utilizados en los niños se programan durante varios días. 		 Score: 0.6579
# -------------------------------------------------------------------------------------------------------------------
# 166.0 		SOURCE: Ante la ausencia de estos datos, el consenso vigente es tratar a los niños de manera similar a los adultos, con el ajuste de dosis adecuado. 		TARGET: Por lo general, se trata a los niños de la misma forma que a los adultos, con dosis de medicamentos contra las náuseas que se ajustan según la edad. 		 Score: 0.6842
# -------------------------------------------------------------------------------------------------------------------
# 167.0 		SOURCE: Náuseas y vómitos anticipatorios en niños 		TARGET: Náuseas y vómitos relacionados con el tratamiento en los niños 		 Score: 0.8460
# -------------------------------------------------------------------------------------------------------------------
# 167.1 		SOURCE: Náuseas y vómitos anticipatorios en niños 		TARGET: Náuseas y vómitos anticipatorios 		 Score: 0.7967
# -------------------------------------------------------------------------------------------------------------------
# 168.0 		SOURCE: Los pacientes de cáncer que ya han recibido quimioterapia quizá padezcan de náuseas y vómitos (NyV) cuando anticipan una quimioterapia. 		TARGET: Es posible que las náuseas y vómitos anticipatorios se presenten después de varios tratamientos de quimioterapia. 		 Score: 0.6808
# -------------------------------------------------------------------------------------------------------------------
# 168.1 		SOURCE: Los pacientes de cáncer que ya han recibido quimioterapia quizá padezcan de náuseas y vómitos (NyV) cuando anticipan una quimioterapia. 		TARGET: Si el paciente sufrió de náuseas y vómitos después de una sesión de quimioterapia anterior, quizá tenga náuseas y vómitos anticipatorios antes del siguiente tratamiento. 		 Score: 0.6552
# -------------------------------------------------------------------------------------------------------------------
# 169.0 		SOURCE: Abordajes para la prevención de las náuseas y vómitos anticipatorios en los niños 		TARGET: Náuseas y vómitos relacionados con el tratamiento en los niños 		 Score: 0.7616
# -------------------------------------------------------------------------------------------------------------------
# 169.1 		SOURCE: Abordajes para la prevención de las náuseas y vómitos anticipatorios en los niños 		TARGET: Los estudios sobre la prevención de las náuseas y vómitos diferidos en niños son pocos. 		 Score: 0.6834
# -------------------------------------------------------------------------------------------------------------------
# 170.0 		SOURCE: Intervenciones para el control de las náuseas y los vómitos anticipatorios 		TARGET: Náuseas y vómitos anticipatorios 		 Score: 0.7073
# -------------------------------------------------------------------------------------------------------------------
# 171.0 		SOURCE: Hipnosis 		TARGET: + Hipnosis. 		 Score: 0.7212
# -------------------------------------------------------------------------------------------------------------------
# 172.0 		SOURCE: Intervenciones farmacológicas 		TARGET: Nombre del medicamento                                           Tipo de medicamento 		 Score: 0.6058
# -------------------------------------------------------------------------------------------------------------------
# 172.1 		SOURCE: Intervenciones farmacológicas 		TARGET: Nombre del medicamento                          Tipo de medicamento 		 Score: 0.6058
# -------------------------------------------------------------------------------------------------------------------
# 174.0 		SOURCE: Los revisores principales del sumario sobre Náuseas y vómitos relacionados con el tratamiento del cáncer son: 		TARGET: Náuseas y vómitos relacionados con el tratamiento del cáncer 		 Score: 0.7184
# -------------------------------------------------------------------------------------------------------------------
# 174.1 		SOURCE: Los revisores principales del sumario sobre Náuseas y vómitos relacionados con el tratamiento del cáncer son: 		TARGET: Para obtener más información del Instituto Nacional del Cáncer sobre náuseas y vómitos relacionados con el tratamiento del cáncer, consulte el siguiente enlace: 		 Score: 0.7054
