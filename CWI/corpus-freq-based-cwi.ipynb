# %% [markdown]
# ## Identify candidate complex words according to corpus frequency

# %%
import re
import sys
import spacy

# %%
# Load frequency data from corpus (lowercase frequency word list)
corpus_freq_list = "/Users/Leonardo 1/Documents/Trabajo/CORPES-XXI/CORPES_091_fre_general_norm_minusc.txt"

FreqData = {}

with open(corpus_freq_list, 'r', encoding="utf-8") as f:
    Lines = f.readlines()
    for line in Lines:
        line.strip()
        word, _, freq = re.search("^([^\t]+)\t([^\t]+)\t([^\t]+)",line).group(1,2,3)
        if word and freq and freq.isdigit() and word not in FreqData.keys():
            FreqData[word] = freq

# %%
def get_word_frequency(word, FreqHash):
    
    ''' Return word frequency from corpus data; if no occurrence in corpus, return 0 '''
    
    word = word.lower()
    
    if word in FreqHash.keys():
        
        return FreqHash[word]
    
    else:
    
        return 0

# %%
def check_word(word):
    
    ''' Checks if a word is a digit, contains a punctuaction character or a space due to tokenization error '''
    
    # Do not check space characters or punctuation signs
    exclusion_chars = ["%", "\n", "\t", "≥", "≤", "/"]
    
    # Do not check numbers
    if str(word).isdigit():
         
        return False 
    
    elif word.is_punct:
        
        return False
    
    for char in exclusion_chars:
        
        if (char in word.text):
            
            return False
    
    return True

# %%
nlp = spacy.load('es_core_news_md')


def sentences_spacy(text, nlp_model):
    
    ''' Split text into sentences (returns a list) '''
    
    doc = nlp_model(text)
    
    Sentences = [sentence for sentence in doc.sents]
    
    return Sentences


def tokenize_spacy(text,nlp_model):

    ''' Given a text from an opened file, tokenizes it with Spacy '''
    
    original_text = text
    
    doc = nlp_model(text)
    
    Tokens={}
    
    for i,token in enumerate(doc):

        # Starting offset: token.idx
        # Ending offset:
        end = str(int(token.idx) + int(len(token.text)))
        
        Tokens[i] = { 'token': token, 'start': token.idx, 'end': end }
        
    return Tokens

# %%
texto_prueba = '''Cáncer de próstata grado 2 confirmado histológicamente, tratado con prostatectomía radical (PR). Se podrá incluir a pacientes sin linfadenectomía.'''

# %%
Sentences = sentences_spacy(texto_prueba,nlp)
Sentences
# Out:
# [Cáncer de próstata grado 2 confirmado histológicamente, tratado con prostatectomía radical (PR).,
#  Se podrá incluir a pacientes sin linfadenectomía.]

# %%
for sentence in Sentences:
    
    print(sentence.text)
    
    Tokens = tokenize_spacy(sentence.text,nlp)
    
    for t in Tokens:
        
        token = Tokens[t]['token']

        # Do not check numbers, spaces or punctuation signs
        if check_word == True:
        
            freq_value = get_word_frequency(str(token),FreqData)
        
            # print(token,freq_value,sep="\t")
            # Frequency value as threshold to filter 
            score = 100
            
            if (int(freq_value) <= score):
                
                print(str(token),freq_value,Tokens[t]['start'],Tokens[t]['end'])
# Out:
# Cáncer de próstata grado 2 confirmado histológicamente, tratado con prostatectomía radical (PR).
# Se podrá incluir a pacientes sin linfadenectomía.

# %% [markdown]
# ### Processing a document

# %%
with open("2021-002864-36.txt", 'r', encoding='utf8') as f:
    
    Lines = f.readlines()
    
    for line in Lines:
    
        Sentences = sentences_spacy(line,nlp)
        
        for sentence in Sentences:
            
            print(sentence.text)
    
            Tokens = tokenize_spacy(sentence.text,nlp)

            for t in Tokens:

                token = Tokens[t]['token']
                
                if check_word(token) == True:
                        
                    freq_value = get_word_frequency(str(token),FreqData)

                    # print(token,freq_value,sep="\t")
                    # Frequency value as threshold to filter 
                    score = 100

                    if (int(freq_value) <= score):

                        print(str(token),"\tFrecuencia:",freq_value,"\tOffsets:",Tokens[t]['start'],Tokens[t]['end'])
# Out:
# Ensayo prospectivo, aleatorizado, doble ciego, controlado con placebo y multicéntrico de fase IIb para evaluar la eficacia y seguridad del mocravimod como tratamiento adyuvante y de mantenimiento en la leucemia mieloide aguda (LMA) en pacientes adultos sometidos a un trasplante alogénico de células madre hematopoyéticas (TCMH)
# aleatorizado 	Frecuencia: 59 	Offsets: 20 32
# IIb 	Frecuencia: 50 	Offsets: 94 97
# mocravimod 	Frecuencia: 0 	Offsets: 139 149
# adyuvante 	Frecuencia: 69 	Offsets: 167 176
# mieloide 	Frecuencia: 57 	Offsets: 211 219
# LMA 	Frecuencia: 51 	Offsets: 227 230
# alogénico 	Frecuencia: 13 	Offsets: 279 288
# hematopoyéticas 	Frecuencia: 54 	Offsets: 306 321
# TCMH 	Frecuencia: 0 	Offsets: 323 327
#
#
#
#
# Ensayo de fase IIb controlado con placebo para evaluar la eficacia y seguridad del mocravimod como tratamiento adyuvante y de mantenimiento en la leucemia mieloide aguda (LMA) en pacientes sometidos a un trasplante alogénico de células madre hematopoyéticas (TCMH) (Estudio Mo-TRANS)
# IIb 	Frecuencia: 50 	Offsets: 15 18
# mocravimod 	Frecuencia: 0 	Offsets: 83 93
# adyuvante 	Frecuencia: 69 	Offsets: 111 120
# mieloide 	Frecuencia: 57 	Offsets: 155 163
# LMA 	Frecuencia: 51 	Offsets: 171 174
# alogénico 	Frecuencia: 13 	Offsets: 215 224
# hematopoyéticas 	Frecuencia: 54 	Offsets: 242 257
# TCMH 	Frecuencia: 0 	Offsets: 259 263
# Mo-TRANS 	Frecuencia: 0 	Offsets: 274 282
#
#
#
#
# Indicación científica: Tratamiento adyuvante y de mantenimiento en la TCMH
# adyuvante 	Frecuencia: 69 	Offsets: 35 44
# TCMH 	Frecuencia: 0 	Offsets: 70 74
#
#
#
#
# Criterios de inclusión
#
#
#
# 1.
# Sujetos con diagnóstico de LMA (excluida la leucemia promielocítica aguda) según la clasificación de 2016 de la Organización Mundial de la Salud (OMS) de la LMA y las neoplasias precursoras relacionadas, incluida la LMA secundaria después de una enfermedad hematológica antecedente (por ejemplo, el síndrome mielodisplásico) y la LMA relacionada con la terapia.
# LMA 	Frecuencia: 51 	Offsets: 27 30
# promielocítica 	Frecuencia: 3 	Offsets: 53 67
# LMA 	Frecuencia: 51 	Offsets: 157 160
# LMA 	Frecuencia: 51 	Offsets: 216 219
# hematológica 	Frecuencia: 18 	Offsets: 257 269
# mielodisplásico 	Frecuencia: 2 	Offsets: 308 323
# LMA 	Frecuencia: 51 	Offsets: 330 333
#
#
# 2.
# Sujetos con LMA de alto riesgo según la European LeukemiaNet (ELN) en RC1, LMA de riesgo intermedio en RC1 si MRDpos, o LMA de cualquier riesgo en RC2.
# LMA 	Frecuencia: 51 	Offsets: 12 15
# LeukemiaNet 	Frecuencia: 0 	Offsets: 49 60
# RC1 	Frecuencia: 5 	Offsets: 70 73
# LMA 	Frecuencia: 51 	Offsets: 75 78
# RC1 	Frecuencia: 5 	Offsets: 103 106
# MRDpos 	Frecuencia: 0 	Offsets: 110 116
# LMA 	Frecuencia: 51 	Offsets: 120 123
# RC2 	Frecuencia: 10 	Offsets: 147 150
#
#
# - La remisión completa se define como: < 5% de blastos en la médula por examen morfológico y ausencia de blastos periféricos circulantes y blastos con bastones de Auer; ausencia de enfermedad extramedular; recuento absoluto de neutrófilos ≥ 1,0x109/L (1000/µL); recuento de plaquetas ≥ 100x109/L (100 000/µL).
# blastos 	Frecuencia: 8 	Offsets: 47 54
# blastos 	Frecuencia: 8 	Offsets: 105 112
# blastos 	Frecuencia: 8 	Offsets: 139 146
# Auer 	Frecuencia: 3 	Offsets: 163 167
# extramedular 	Frecuencia: 4 	Offsets: 192 204
# neutrófilos 	Frecuencia: 90 	Offsets: 227 238
# 1,0x109 	Frecuencia: 0 	Offsets: 241 248
# 100x109 	Frecuencia: 0 	Offsets: 286 293
#
#
# 3.
# Sujetos que tienen previsto someterse a un TCMH alogénico
#
# someterse 	Frecuencia: 0 	Offsets: 28 37
# TCMH 	Frecuencia: 0 	Offsets: 43 47
# alogénico 	Frecuencia: 13 	Offsets: 48 57
# 4.
# Esperanza de vida ≥ 6 meses en el momento de la selección.
#
#
# 5.
# Estado de rendimiento del Eastern Cooperative Oncology Group (ECOG) de 0 o 1.
# Eastern 	Frecuencia: 32 	Offsets: 26 33
# Cooperative 	Frecuencia: 18 	Offsets: 34 45
# Oncology 	Frecuencia: 85 	Offsets: 46 54
# ECOG 	Frecuencia: 6 	Offsets: 62 66
#
#
# 6.
# Hombre o mujer, edad ≥ 18 años y ≤ 75 años.
#
#
#
#
# Criterios de exclusión
#
#
#
# 1.
# Uso previsto de globulina antitimocítica (ATG), ciclofosfamida postrasplante, sirolimus, micofenolato mofetilo, abatacept o cualquier medicamento aprobado o no aprobado que no sea MTX más CsA o MTX más TAC para la profilaxis de la EICH.
# globulina 	Frecuencia: 14 	Offsets: 16 25
# antitimocítica 	Frecuencia: 0 	Offsets: 26 40
# ATG 	Frecuencia: 3 	Offsets: 42 45
# ciclofosfamida 	Frecuencia: 22 	Offsets: 48 62
# postrasplante 	Frecuencia: 5 	Offsets: 63 76
# sirolimus 	Frecuencia: 8 	Offsets: 78 87
# micofenolato 	Frecuencia: 4 	Offsets: 89 101
# mofetilo 	Frecuencia: 0 	Offsets: 102 110
# abatacept 	Frecuencia: 2 	Offsets: 112 121
# MTX 	Frecuencia: 9 	Offsets: 180 183
# CsA 	Frecuencia: 64 	Offsets: 188 191
# MTX 	Frecuencia: 9 	Offsets: 194 197
# EICH 	Frecuencia: 7 	Offsets: 231 235
#
#
# 2.Uso previsto de sueroterapia durante el acondicionamiento, incluyendo ATG y alemtuzumab.
# 2.Uso 	Frecuencia: 1 	Offsets: 0 5
# sueroterapia 	Frecuencia: 23 	Offsets: 18 30
# ATG 	Frecuencia: 3 	Offsets: 72 75
# alemtuzumab 	Frecuencia: 4 	Offsets: 78 89
#
#
# 3.
# Manipulación ex vivo del injerto principal, incluida la depleción de células T o la selección de CD34+.
# depleción 	Frecuencia: 62 	Offsets: 56 65
# CD34 	Frecuencia: 7 	Offsets: 97 101
#
#
# 4.
# Sujetos que hayan recibido un TCMH alogénico previo o receptores de un trasplante de órgano sólido.
# TCMH 	Frecuencia: 0 	Offsets: 30 34
# alogénico 	Frecuencia: 13 	Offsets: 35 44
#
#
# 5.
# Fármacos inmunosupresores para enfermedades concomitantes.
# inmunosupresores 	Frecuencia: 56 	Offsets: 9 25
# Los sujetos deben poder estar sin prednisona (> 10 mg/día) u otros medicamentos inmunosupresores durante al menos 3 días antes del inicio del tratamiento del estudio.
# prednisona 	Frecuencia: 36 	Offsets: 34 44
# inmunosupresores 	Frecuencia: 56 	Offsets: 80 96
# Se permite la dosificación fisiológica de sustitución de hidrocortisona.
# hidrocortisona 	Frecuencia: 29 	Offsets: 57 71
#
#
# 6.
# Requerir tratamientos para la disfunción cardíaca
#
# 7.
# Sujetos con leucemia promielocítica aguda.
# promielocítica 	Frecuencia: 3 	Offsets: 21 35
#
#
# 8.
# Crisis blástica de leucemia mieloide crónica
#
# blástica 	Frecuencia: 2 	Offsets: 7 15
# mieloide 	Frecuencia: 57 	Offsets: 28 36
# 9.
# Disfunción cardíaca
#
#
# 10.
# Disfunción pulmonar.
#
#
# 11.
# Enfermedad hepática significativa o lesión hepática o historia conocida de abuso de alcohol, enfermedad hepática o biliar crónica.
# Disfunción hepática definida por aspartato aminotransferasa (AST) y/o alanina aminotransferasa (ALT) > 2,5 x límite superior de la normalidad (ULN); o bilirrubina total > 1,5 x ULN
# aspartato 	Frecuencia: 22 	Offsets: 33 42
# aminotransferasa 	Frecuencia: 13 	Offsets: 43 59
# AST 	Frecuencia: 49 	Offsets: 61 64
# alanina 	Frecuencia: 16 	Offsets: 70 77
# aminotransferasa 	Frecuencia: 13 	Offsets: 78 94
# ULN 	Frecuencia: 0 	Offsets: 143 146
# bilirrubina 	Frecuencia: 95 	Offsets: 151 162
# ULN 	Frecuencia: 0 	Offsets: 177 180
#
#
# 12.
# Disfunción renal con aclaramiento de creatinina < 60 mL/min según la fórmula de Cockcroft-Gault.
# aclaramiento 	Frecuencia: 38 	Offsets: 21 33
# Cockcroft-Gault 	Frecuencia: 2 	Offsets: 80 95
#
#
# 13.
# Antecedentes de ictus o hemorragia intracraneal en el plazo de 1 año antes la selección.
# intracraneal 	Frecuencia: 81 	Offsets: 35 47
#
#
# 14.
# Infección activa clínicamente significativa (vírica, bacteriana o fúngica) que requiera un tratamiento antimicrobiano continuado y que, a juicio del investigador, represente un riesgo para proceder al TCMH.
# fúngica 	Frecuencia: 40 	Offsets: 66 73
# antimicrobiano 	Frecuencia: 79 	Offsets: 103 117
# TCMH 	Frecuencia: 0 	Offsets: 201 205
